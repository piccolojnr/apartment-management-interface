# %%
import paho.mqtt.client as mqtt

# The callback for when the client receives a CONNACK response from the server.
def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    # Subscribing in on_connect() means that if we lose the connection and
    # reconnect then subscriptions will be renewed.
    client.subscribe("$SYS/#")

# The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
    print(msg.topic+" "+str(msg.payload))

mqttc = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
mqttc.on_connect = on_connect
mqttc.on_message = on_message

mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)

# Blocking call that processes network traffic, dispatches callbacks and
# handles reconnecting.
# Other loop*() functions are available that give a threaded interface and a
# manual interface.
mqttc.loop_forever()
# Out:
# Connected with result code Success
# $SYS/broker/version b'mosquitto version 2.0.18'
# $SYS/broker/uptime b'190333 seconds'
# $SYS/broker/clients/total b'2163'
# $SYS/broker/clients/inactive b'336'
# $SYS/broker/clients/disconnected b'336'
# $SYS/broker/clients/active b'1827'
# $SYS/broker/clients/connected b'1827'
# $SYS/broker/clients/expired b'115'
# $SYS/broker/clients/maximum b'2361'
# $SYS/broker/load/messages/received/1min b'279572.31'
# $SYS/broker/load/messages/received/5min b'279211.40'
# $SYS/broker/load/messages/received/15min b'278541.90'
# $SYS/broker/load/messages/sent/1min b'877368.41'
# $SYS/broker/load/messages/sent/5min b'947567.21'
# $SYS/broker/load/messages/sent/15min b'1044571.24'
# $SYS/broker/load/publish/dropped/1min b'407.48'
# $SYS/broker/load/publish/dropped/5min b'11239.51'
# $SYS/broker/load/publish/dropped/15min b'10679.46'
# $SYS/broker/load/publish/received/1min b'269100.37'
# $SYS/broker/load/publish/received/5min b'268925.82'
# $SYS/broker/load/publish/received/15min b'268145.22'
# $SYS/broker/load/publish/sent/1min b'865484.29'
# $SYS/broker/load/publish/sent/5min b'935910.00'
# $SYS/broker/load/publish/sent/15min b'1032814.75'
# $SYS/broker/load/bytes/received/1min b'15340196.93'
# $SYS/broker/load/bytes/received/5min b'15325073.87'
# $SYS/broker/load/bytes/received/15min b'15287288.82'
# $SYS/broker/load/bytes/sent/1min b'49949487.56'
# $SYS/broker/load/bytes/sent/5min b'53845974.30'
# $SYS/broker/load/bytes/sent/15min b'59284621.31'
# $SYS/broker/load/sockets/1min b'889.07'
# $SYS/broker/load/sockets/5min b'904.81'
# $SYS/broker/load/sockets/15min b'934.73'
# $SYS/broker/load/connections/1min b'805.66'
# $SYS/broker/load/connections/5min b'824.17'
# $SYS/broker/load/connections/15min b'855.72'
# $SYS/broker/messages/stored b'92958'
# $SYS/broker/messages/received b'865757696'
# $SYS/broker/messages/sent b'2262389321'
# $SYS/broker/store/messages/count b'92958'
# $SYS/broker/store/messages/bytes b'3030522'
# $SYS/broker/subscriptions/count b'38036'
# $SYS/broker/shared_subscriptions/count b'0'
# $SYS/broker/retained messages/count b'53260'
# $SYS/broker/heap/current b'843912840'
# $SYS/broker/heap/maximum b'845530528'
# $SYS/broker/publish/messages/dropped b'23799746'
# $SYS/broker/publish/messages/received b'714333290'
# $SYS/broker/publish/messages/sent b'2109697139'
# $SYS/broker/publish/bytes/received b'18527632859'
# $SYS/broker/publish/bytes/sent b'66662118314'
# $SYS/broker/bytes/received b'51591176880'
# $SYS/broker/bytes/sent b'158923290090'
# $SYS/broker/connection/ks4.ral.me.eclipse/state b'1'
# $SYS/broker/connection/raspberryweewx.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/raspberrypi.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/raspberrypiwll.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/233ca3e444ac.eclipseprojects/state b'1'
# $SYS/broker/connection/GP-reh.bridge/state b'0'
# $SYS/broker/connection/weewx-raspi5.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/OpenWrtN600.eclipseprojects.io/state b'1'
# $SYS/broker/connection/Weewx.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/openhabian.eclipseprojects/state b'1'
# $SYS/broker/connection/weewx-ubuntu.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/ursolandia/state b'1'
# $SYS/broker/connection/bananapim2plus.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/hab.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/98bc5f276668.bridge-to-eclipse/state b'1'
# $SYS/broker/connection/Marco-Medrano.conn-broker1/state b'0'
# $SYS/broker/uptime b'190344 seconds'
# $SYS/broker/clients/total b'2160'
# $SYS/broker/clients/inactive b'334'
# $SYS/broker/clients/disconnected b'334'
# $SYS/broker/clients/active b'1826'
# $SYS/broker/clients/connected b'1826'
# $SYS/broker/load/messages/received/1min b'279396.04'
# $SYS/broker/load/messages/sent/1min b'878297.75'
# $SYS/broker/load/publish/dropped/1min b'339.22'
# $SYS/broker/load/publish/received/1min b'269402.74'
# $SYS/broker/load/publish/sent/1min b'866911.36'
# $SYS/broker/load/bytes/received/1min b'15405487.73'
# $SYS/broker/load/bytes/sent/1min b'50401620.33'
# $SYS/broker/load/sockets/1min b'884.50'
# $SYS/broker/load/connections/1min b'799.53'
# $SYS/broker/load/messages/received/5min b'279186.51'
# $SYS/broker/load/messages/sent/5min b'945239.61'
# $SYS/broker/load/publish/dropped/5min b'10834.86'
# $SYS/broker/load/publish/received/5min b'268997.09'
# $SYS/broker/load/publish/sent/5min b'933681.21'
# $SYS/broker/load/bytes/received/5min b'15339651.21'
# $SYS/broker/load/bytes/sent/5min b'53802867.04'
# $SYS/broker/load/sockets/5min b'903.27'
# $SYS/broker/load/connections/5min b'822.18'
# $SYS/broker/load/messages/received/15min b'278541.63'
# $SYS/broker/load/messages/sent/15min b'1042607.49'
# $SYS/broker/load/publish/dropped/15min b'10549.73'
# $SYS/broker/load/publish/received/15min b'268178.75'
# $SYS/broker/load/publish/sent/15min b'1030885.54'
# $SYS/broker/load/bytes/received/15min b'15292666.45'
# $SYS/broker/load/bytes/sent/15min b'59204008.47'
# $SYS/broker/load/sockets/15min b'933.84'
# $SYS/broker/load/connections/15min b'854.66'
# $SYS/broker/messages/stored b'92955'
# $SYS/broker/store/messages/count b'92955'
# $SYS/broker/store/messages/bytes b'3030554'
# $SYS/broker/subscriptions/count b'38063'
# $SYS/broker/retained messages/count b'53258'
# $SYS/broker/heap/current b'843920352'
# $SYS/broker/messages/received b'865808758'
# $SYS/broker/messages/sent b'2262551291'
# $SYS/broker/publish/messages/received b'714382956'
# $SYS/broker/publish/messages/sent b'2109857481'
# $SYS/broker/bytes/received b'51594060708'
# $SYS/broker/bytes/sent b'158932947590'
# $SYS/broker/publish/bytes/received b'18528304141'
# $SYS/broker/publish/bytes/sent b'66664704426'
# $SYS/broker/uptime b'190355 seconds'
# $SYS/broker/clients/total b'2162'
# $SYS/broker/clients/active b'1828'
# $SYS/broker/clients/connected b'1828'
# $SYS/broker/load/messages/received/1min b'280752.31'
# $SYS/broker/load/messages/sent/1min b'881551.16'
# $SYS/broker/load/publish/dropped/1min b'282.40'
# $SYS/broker/load/publish/received/1min b'270186.22'
# $SYS/broker/load/publish/sent/1min b'869599.66'
# $SYS/broker/load/bytes/received/1min b'15437469.16'
# $SYS/broker/load/bytes/sent/1min b'50461719.90'
# $SYS/broker/load/sockets/1min b'867.00'
# $SYS/broker/load/connections/1min b'785.30'
# $SYS/broker/load/messages/received/5min b'279485.55'
# $SYS/broker/load/messages/sent/5min b'943528.79'
# $SYS/broker/load/publish/dropped/5min b'10444.78'
# $SYS/broker/load/publish/received/5min b'269180.09'
# $SYS/broker/load/publish/sent/5min b'931855.12'
# $SYS/broker/load/bytes/received/5min b'15348895.22'
# $SYS/broker/load/bytes/sent/5min b'53693330.49'
# $SYS/broker/load/sockets/5min b'898.83'
# $SYS/broker/load/connections/5min b'818.31'
# $SYS/broker/load/messages/received/15min b'278650.37'
# $SYS/broker/load/messages/sent/15min b'1040847.42'
# $SYS/broker/load/publish/dropped/15min b'10421.57'
# $SYS/broker/load/publish/received/15min b'268250.44'
# $SYS/broker/load/publish/sent/15min b'1029088.57'
# $SYS/broker/load/bytes/received/15min b'15296356.28'
# $SYS/broker/load/bytes/sent/15min b'59101436.95'
# $SYS/broker/load/sockets/15min b'931.97'
# $SYS/broker/load/connections/15min b'852.96'
# $SYS/broker/messages/stored b'92966'
# $SYS/broker/store/messages/count b'92966'
# $SYS/broker/store/messages/bytes b'3031007'
# $SYS/broker/subscriptions/count b'38030'
# $SYS/broker/retained messages/count b'53260'
# $SYS/broker/heap/current b'843907440'
# $SYS/broker/messages/received b'865861465'
# $SYS/broker/messages/sent b'2262715975'
# $SYS/broker/publish/messages/received b'714433204'
# $SYS/broker/publish/messages/sent b'2110019465'
# $SYS/broker/bytes/received b'51596920050'
# $SYS/broker/bytes/sent b'158942258914'
# $SYS/broker/publish/bytes/received b'18528924850'
# $SYS/broker/publish/bytes/sent b'66666896889'
# $SYS/broker/uptime b'190366 seconds'
# $SYS/broker/clients/total b'2159'
# $SYS/broker/clients/active b'1825'
# $SYS/broker/clients/connected b'1825'
# $SYS/broker/load/messages/received/1min b'280308.02'
# $SYS/broker/load/messages/sent/1min b'880411.14'
# $SYS/broker/load/publish/dropped/1min b'235.09'
# $SYS/broker/load/publish/received/1min b'270210.76'
# $SYS/broker/load/publish/sent/1min b'868963.18'
# $SYS/broker/load/bytes/received/1min b'15389425.93'
# $SYS/broker/load/bytes/sent/1min b'50202143.71'
# $SYS/broker/load/sockets/1min b'858.82'
# $SYS/broker/load/connections/1min b'775.27'
# $SYS/broker/load/messages/received/5min b'279435.67'
# $SYS/broker/load/messages/sent/5min b'941052.41'
# $SYS/broker/load/publish/dropped/5min b'10068.74'
# $SYS/broker/load/publish/received/5min b'269221.59'
# $SYS/broker/load/publish/sent/5min b'929476.96'
# $SYS/broker/load/bytes/received/5min b'15341758.24'
# $SYS/broker/load/bytes/sent/5min b'53521193.76'
# $SYS/broker/load/sockets/5min b'895.92'
# $SYS/broker/load/connections/5min b'814.97'
# $SYS/broker/load/messages/received/15min b'278643.68'
# $SYS/broker/load/messages/sent/15min b'1038829.64'
# $SYS/broker/load/publish/dropped/15min b'10294.97'
# $SYS/broker/load/publish/received/15min b'268275.73'
# $SYS/broker/load/publish/sent/15min b'1027104.96'
# $SYS/broker/load/bytes/received/15min b'15294586.39'
# $SYS/broker/load/bytes/sent/15min b'58977658.56'
# $SYS/broker/load/sockets/15min b'930.59'
# $SYS/broker/load/connections/15min b'851.41'
# $SYS/broker/messages/stored b'93050'
# $SYS/broker/store/messages/count b'93050'
# $SYS/broker/store/messages/bytes b'3032035'
# $SYS/broker/subscriptions/count b'37972'
# $SYS/broker/heap/current b'843910904'
# $SYS/broker/messages/received b'865912450'
# $SYS/broker/messages/sent b'2262876444'
# $SYS/broker/publish/messages/received b'714482765'
# $SYS/broker/publish/messages/sent b'2110178300'
# $SYS/broker/bytes/received b'51599697671'
# $SYS/broker/bytes/sent b'158951231250'
# $SYS/broker/publish/bytes/received b'18529506837'
# $SYS/broker/publish/bytes/sent b'66668926956'
# $SYS/broker/uptime b'190377 seconds'
# $SYS/broker/clients/total b'2162'
# $SYS/broker/clients/inactive b'336'
# $SYS/broker/clients/disconnected b'336'
# $SYS/broker/clients/active b'1826'
# $SYS/broker/clients/connected b'1826'
# $SYS/broker/load/messages/received/1min b'278465.30'
# $SYS/broker/load/messages/sent/1min b'875208.87'
# $SYS/broker/load/publish/dropped/1min b'195.71'
# $SYS/broker/load/publish/received/1min b'268811.32'
# $SYS/broker/load/publish/sent/1min b'864144.47'
# $SYS/broker/load/bytes/received/1min b'15335441.84'
# $SYS/broker/load/bytes/sent/1min b'49949188.99'
# $SYS/broker/load/sockets/1min b'853.84'
# $SYS/broker/load/connections/1min b'770.58'
# $SYS/broker/load/messages/received/5min b'279071.02'
# $SYS/broker/load/messages/sent/5min b'937751.05'
# $SYS/broker/load/publish/dropped/5min b'9706.24'
# $SYS/broker/load/publish/received/5min b'268956.42'
# $SYS/broker/load/publish/sent/5min b'926262.63'
# $SYS/broker/load/bytes/received/5min b'15331871.67'
# $SYS/broker/load/bytes/sent/5min b'53347332.13'
# $SYS/broker/load/sockets/5min b'893.52'
# $SYS/broker/load/connections/5min b'812.53'
# $SYS/broker/load/messages/received/15min b'278530.27'
# $SYS/broker/load/messages/sent/15min b'1036527.93'
# $SYS/broker/load/publish/dropped/15min b'10169.91'
# $SYS/broker/load/publish/received/15min b'268197.75'
# $SYS/broker/load/publish/sent/15min b'1024834.43'
# $SYS/broker/load/bytes/received/15min b'15291823.54'
# $SYS/broker/load/bytes/sent/15min b'58852710.70'
# $SYS/broker/load/sockets/15min b'929.36'
# $SYS/broker/load/connections/15min b'850.15'
# $SYS/broker/messages/stored b'93052'
# $SYS/broker/store/messages/count b'93052'
# $SYS/broker/store/messages/bytes b'3031966'
# $SYS/broker/subscriptions/count b'38050'
# $SYS/broker/heap/current b'843935176'
# $SYS/broker/messages/received b'865961823'
# $SYS/broker/messages/sent b'2263032258'
# $SYS/broker/publish/messages/received b'714530772'
# $SYS/broker/publish/messages/sent b'2110332441'
# $SYS/broker/bytes/received b'51602459982'
# $SYS/broker/bytes/sent b'158960163241'
# $SYS/broker/publish/bytes/received b'18530121090'
# $SYS/broker/publish/bytes/sent b'66671051999'
# $SYS/broker/uptime b'190388 seconds'
# $SYS/broker/clients/total b'2164'
# $SYS/broker/clients/active b'1828'
# $SYS/broker/clients/connected b'1828'
# $SYS/broker/load/messages/received/1min b'279163.38'
# $SYS/broker/load/messages/sent/1min b'876639.74'
# $SYS/broker/load/publish/dropped/1min b'162.93'
# $SYS/broker/load/publish/received/1min b'268869.73'
# $SYS/broker/load/publish/sent/1min b'864957.20'
# $SYS/broker/load/bytes/received/1min b'15330256.96'
# $SYS/broker/load/bytes/sent/1min b'49979127.51'
# $SYS/broker/load/sockets/1min b'845.13'
# $SYS/broker/load/connections/1min b'765.76'
# $SYS/broker/load/messages/received/5min b'279199.25'
# $SYS/broker/load/messages/sent/5min b'935806.90'
# $SYS/broker/load/publish/dropped/5min b'9356.79'
# $SYS/broker/load/publish/received/5min b'268963.75'
# $SYS/broker/load/publish/sent/5min b'924200.89'
# $SYS/broker/load/bytes/received/5min b'15330885.82'
# $SYS/broker/load/bytes/sent/5min b'53231424.84'
# $SYS/broker/load/sockets/5min b'890.22'
# $SYS/broker/load/connections/5min b'809.98'
# $SYS/broker/load/messages/received/15min b'278580.10'
# $SYS/broker/load/messages/sent/15min b'1034672.02'
# $SYS/broker/load/publish/dropped/15min b'10046.37'
# $SYS/broker/load/publish/received/15min b'268209.44'
# $SYS/broker/load/publish/sent/15min b'1022941.33'
# $SYS/broker/load/bytes/received/15min b'15291977.40'
# $SYS/broker/load/bytes/sent/15min b'58746723.34'
# $SYS/broker/load/sockets/15min b'927.81'
# $SYS/broker/load/connections/15min b'848.83'
# $SYS/broker/messages/stored b'93075'
# $SYS/broker/store/messages/count b'93075'
# $SYS/broker/store/messages/bytes b'3041815'
# $SYS/broker/subscriptions/count b'38097'
# $SYS/broker/retained messages/count b'53258'
# $SYS/broker/heap/current b'843972792'
# $SYS/broker/messages/received b'866013639'
# $SYS/broker/messages/sent b'2263194381'
# $SYS/broker/publish/messages/received b'714580118'
# $SYS/broker/publish/messages/sent b'2110491865'
# $SYS/broker/bytes/received b'51605265805'
# $SYS/broker/bytes/sent b'158969358606'
# $SYS/broker/publish/bytes/received b'18530718300'
# $SYS/broker/publish/bytes/sent b'66673213831'
# $SYS/broker/uptime b'190399 seconds'
# $SYS/broker/clients/total b'2161'
# $SYS/broker/clients/inactive b'338'
# $SYS/broker/clients/disconnected b'338'
# $SYS/broker/clients/active b'1823'
# $SYS/broker/clients/connected b'1823'
# $SYS/broker/load/messages/received/1min b'280259.85'
# $SYS/broker/load/messages/sent/1min b'880850.66'
# $SYS/broker/load/publish/dropped/1min b'135.64'
# $SYS/broker/load/publish/received/1min b'270174.67'
# $SYS/broker/load/publish/sent/1min b'869405.50'
# $SYS/broker/load/bytes/received/1min b'15384925.53'
# $SYS/broker/load/bytes/sent/1min b'50120719.80'
# $SYS/broker/load/sockets/1min b'837.87'
# $SYS/broker/load/connections/1min b'759.92'
# $SYS/broker/load/messages/received/5min b'279433.62'
# $SYS/broker/load/messages/sent/5min b'934581.78'
# $SYS/broker/load/publish/dropped/5min b'9019.92'
# $SYS/broker/load/publish/received/5min b'269240.84'
# $SYS/broker/load/publish/sent/5min b'923024.04'
# $SYS/broker/load/bytes/received/5min b'15342613.03'
# $SYS/broker/load/bytes/sent/5min b'53144765.98'
# $SYS/broker/load/sockets/5min b'887.03'
# $SYS/broker/load/connections/5min b'807.14'
# $SYS/broker/load/messages/received/15min b'278666.70'
# $SYS/broker/load/messages/sent/15min b'1033057.64'
# $SYS/broker/load/publish/dropped/15min b'9924.33'
# $SYS/broker/load/publish/received/15min b'268312.10'
# $SYS/broker/load/publish/sent/15min b'1021344.76'
# $SYS/broker/load/bytes/received/15min b'15296407.00'
# $SYS/broker/load/bytes/sent/15min b'58650484.36'
# $SYS/broker/load/sockets/15min b'926.28'
# $SYS/broker/load/connections/15min b'847.40'
# $SYS/broker/store/messages/bytes b'3041800'
# $SYS/broker/subscriptions/count b'38124'
# $SYS/broker/retained messages/count b'53260'
# $SYS/broker/heap/current b'843968728'
# $SYS/broker/messages/received b'866066019'
# $SYS/broker/messages/sent b'2263359803'
# $SYS/broker/publish/messages/received b'714630839'
# $SYS/broker/publish/messages/sent b'2110655411'
# $SYS/broker/bytes/received b'51608136185'
# $SYS/broker/bytes/sent b'158978681427'
# $SYS/broker/publish/bytes/received b'18531326113'
# $SYS/broker/publish/bytes/sent b'66675350673'
# $SYS/broker/uptime b'190410 seconds'
# $SYS/broker/clients/inactive b'339'
# $SYS/broker/clients/disconnected b'339'
# $SYS/broker/clients/active b'1822'
# $SYS/broker/clients/connected b'1822'
# $SYS/broker/load/messages/received/1min b'279089.44'
# $SYS/broker/load/messages/sent/1min b'877920.20'
# $SYS/broker/load/publish/dropped/1min b'112.92'
# $SYS/broker/load/publish/received/1min b'269440.05'
# $SYS/broker/load/publish/sent/1min b'866944.02'
# $SYS/broker/load/bytes/received/1min b'15311216.82'
# $SYS/broker/load/bytes/sent/1min b'49902582.72'
# $SYS/broker/load/sockets/1min b'819.95'
# $SYS/broker/load/connections/1min b'740.45'
# $SYS/broker/load/messages/received/5min b'279211.81'
# $SYS/broker/load/messages/sent/5min b'932017.48'
# $SYS/broker/load/publish/dropped/5min b'8695.18'
# $SYS/broker/load/publish/received/5min b'269116.57'
# $SYS/broker/load/publish/sent/5min b'920564.59'
# $SYS/broker/load/bytes/received/5min b'15328294.27'
# $SYS/broker/load/bytes/sent/5min b'52989008.57'
# $SYS/broker/load/sockets/5min b'881.41'
# $SYS/broker/load/connections/5min b'801.25'
# $SYS/broker/load/messages/received/15min b'278601.18'
# $SYS/broker/load/messages/sent/15min b'1030996.14'
# $SYS/broker/load/publish/dropped/15min b'9803.77'
# $SYS/broker/load/publish/received/15min b'268281.45'
# $SYS/broker/load/publish/sent/15min b'1019320.52'
# $SYS/broker/load/bytes/received/15min b'15292136.92'
# $SYS/broker/load/bytes/sent/15min b'58531046.82'
# $SYS/broker/load/sockets/15min b'923.90'
# $SYS/broker/load/connections/15min b'844.92'
# $SYS/broker/messages/stored b'93077'
# $SYS/broker/store/messages/count b'93077'
# $SYS/broker/store/messages/bytes b'3041906'
# $SYS/broker/subscriptions/count b'38111'
# $SYS/broker/heap/current b'843975912'
# $SYS/broker/messages/received b'866116119'
# $SYS/broker/messages/sent b'2263518184'
# $SYS/broker/publish/messages/received b'714679567'
# $SYS/broker/publish/messages/sent b'2110812213'
# $SYS/broker/bytes/received b'51610876083'
# $SYS/broker/bytes/sent b'158987636594'
# $SYS/broker/publish/bytes/received b'18531912564'
# $SYS/broker/publish/bytes/sent b'66677453189'
# $SYS/broker/uptime b'190421 seconds'
# $SYS/broker/clients/total b'2162'
# $SYS/broker/clients/inactive b'335'
# $SYS/broker/clients/disconnected b'335'
# $SYS/broker/clients/active b'1827'
# $SYS/broker/clients/connected b'1827'
# $SYS/broker/load/messages/received/1min b'279276.38'
# $SYS/broker/load/messages/sent/1min b'876731.46'
# $SYS/broker/load/publish/dropped/1min b'94.00'
# $SYS/broker/load/publish/received/1min b'268895.18'
# $SYS/broker/load/publish/sent/1min b'865031.91'
# $SYS/broker/load/bytes/received/1min b'15247388.05'
# $SYS/broker/load/bytes/sent/1min b'49610912.78'
# $SYS/broker/load/sockets/1min b'818.74'
# $SYS/broker/load/connections/1min b'737.93'
# $SYS/broker/load/messages/received/5min b'279247.59'
# $SYS/broker/load/messages/sent/5min b'929814.35'
# $SYS/broker/load/publish/dropped/5min b'8382.13'
# $SYS/broker/load/publish/received/5min b'269011.10'
# $SYS/broker/load/publish/sent/5min b'918223.14'
# $SYS/broker/load/bytes/received/5min b'15313960.80'
# $SYS/broker/load/bytes/sent/5min b'52815201.00'
# $SYS/broker/load/sockets/5min b'878.94'
# $SYS/broker/load/connections/5min b'798.52'
# $SYS/broker/load/messages/received/15min b'278620.67'
# $SYS/broker/load/messages/sent/15min b'1029050.39'
# $SYS/broker/load/publish/dropped/15min b'9684.67'
# $SYS/broker/load/publish/received/15min b'268256.01'
# $SYS/broker/load/publish/sent/15min b'1017330.81'
# $SYS/broker/load/bytes/received/15min b'15287739.82'
# $SYS/broker/load/bytes/sent/15min b'58405077.68'
# $SYS/broker/load/sockets/15min b'922.55'
# $SYS/broker/load/connections/15min b'843.47'
# $SYS/broker/messages/stored b'93075'
# $SYS/broker/store/messages/count b'93075'
# $SYS/broker/store/messages/bytes b'3041868'
# $SYS/broker/subscriptions/count b'38036'
# $SYS/broker/retained messages/count b'53259'
# $SYS/broker/heap/current b'843950848'
# $SYS/broker/messages/received b'866167490'
# $SYS/broker/messages/sent b'2263677937'
# $SYS/broker/publish/messages/received b'714728368'
# $SYS/broker/publish/messages/sent b'2110969168'
# $SYS/broker/bytes/received b'51613613281'
# $SYS/broker/bytes/sent b'158996471419'
# $SYS/broker/publish/bytes/received b'18532468815'
# $SYS/broker/publish/bytes/sent b'66679390834'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 24
#      18 mqttc.connect("mqtt.eclipseprojects.io", 1883, 60)
#      20 # Blocking call that processes network traffic, dispatches callbacks and
#      21 # handles reconnecting.
#      22 # Other loop*() functions are available that give a threaded interface and a
#      23 # manual interface.
# ---> 24 mqttc.loop_forever()
#
# File c:\Users\rahim\anaconda3\Lib\site-packages\paho\mqtt\client.py:2297, in Client.loop_forever(self, timeout, retry_first_connection)
#    2295 rc = MQTTErrorCode.MQTT_ERR_SUCCESS
#    2296 while rc == MQTTErrorCode.MQTT_ERR_SUCCESS:
# -> 2297     rc = self._loop(timeout)
#    2298     # We don't need to worry about locking here, because we've
#    2299     # either called loop_forever() when in single threaded mode, or
#    2300     # in multi threaded mode when loop_stop() has been called and
#    2301     # so no other threads can access _out_packet or _messages.
#    2302     if (self._thread_terminate is True
#    2303         and len(self._out_packet) == 0
#    2304             and len(self._out_messages) == 0):
#
# File c:\Users\rahim\anaconda3\Lib\site-packages\paho\mqtt\client.py:1663, in Client._loop(self, timeout)
#    1660     rlist = [self._sock, self._sockpairR]
#    1662 try:
# -> 1663     socklist = select.select(rlist, wlist, [], timeout)
#    1664 except TypeError:
#    1665     # Socket isn't correct type, in likelihood connection is lost
#    1666     # ... or we called disconnect(). In that case the socket will
#    (...)
#    1669     # rc != MQTT_ERR_SUCCESS and we don't want state to change from
#    1670     # mqtt_cs_disconnecting.
#    1671     if self._state not in (_ConnectionState.MQTT_CS_DISCONNECTING, _ConnectionState.MQTT_CS_DISCONNECTED):
#
# KeyboardInterrupt:
